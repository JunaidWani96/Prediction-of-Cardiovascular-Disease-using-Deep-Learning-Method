# %% [markdown]
# <br>
# <br>
# <h1 align="center">Data Analysis and Data visualization </h1>
# <br>
# <br>

# %% [markdown]
# <h3>Importing Dependencies</h3>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <br>
# <br>
# <h1 align="center">Data Analysis</h1>
# <hr>
# <br>
# <br>

# %% [markdown]
# <br>
# <h3>importing dataset</h3>
# <hr>
#
# <br>

# %%
df = pd.read_csv('dataset.csv')

# %%
df.head()
# Out:
#    age  sex  chest pain type  resting bp s  cholesterol  fasting blood sugar  \
# 0   40    1                2           140          289                    0
# 1   49    0                3           160          180                    0
# 2   37    1                2           130          283                    0
# 3   48    0                4           138          214                    0
# 4   54    1                3           150          195                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# 0            0             172                0      0.0         1       0
# 1            0             156                0      1.0         2       1
# 2            1              98                0      0.0         1       0
# 3            0             108                1      1.5         2       1
# 4            0             122                0      0.0         1       0

# %% [markdown]
# <br>
# <h3>Information about Dataset</h3>
# <hr>
# <br>

# %%
# dataset Shape means row and column in dataset
df.shape
# Out:
# (1190, 12)

# %%
# dataset columns names
df.columns
# Out:
# Index(['age', 'sex', 'chest pain type', 'resting bp s', 'cholesterol',
#        'fasting blood sugar', 'resting ecg', 'max heart rate',
#        'exercise angina', 'oldpeak', 'ST slope', 'target'],
#       dtype='object')

# %%
# each dataset field data type
df.dtypes
# Out:
# age                      int64
# sex                      int64
# chest pain type          int64
# resting bp s             int64
# cholesterol              int64
# fasting blood sugar      int64
# resting ecg              int64
# max heart rate           int64
# exercise angina          int64
# oldpeak                float64
# ST slope                 int64
# target                   int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1190 entries, 0 to 1189
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  1190 non-null   int64
#  1   sex                  1190 non-null   int64
#  2   chest pain type      1190 non-null   int64
#  3   resting bp s         1190 non-null   int64
#  4   cholesterol          1190 non-null   int64
#  5   fasting blood sugar  1190 non-null   int64
#  6   resting ecg          1190 non-null   int64
#  7   max heart rate       1190 non-null   int64
#  8   exercise angina      1190 non-null   int64
#  9   oldpeak              1190 non-null   float64
#  10  ST slope             1190 non-null   int64
#  11  target               1190 non-null   int64
# dtypes: float64(1), int64(11)
# memory usage: 111.7 KB

# %%
# This method is use to check Null values in a dataset
df.isnull().sum()
# Out:
# age                    0
# sex                    0
# chest pain type        0
# resting bp s           0
# cholesterol            0
# fasting blood sugar    0
# resting ecg            0
# max heart rate         0
# exercise angina        0
# oldpeak                0
# ST slope               0
# target                 0
# dtype: int64

# %% [markdown]
# <br>
# <h3>Checking catagorical variable value and removing extra value from it</h3>
# <hr>
# <br>

# %%
df['sex'].unique()
# Out:
# array([1, 0])

# %%
df['chest pain type'].unique()
# Out:
# array([2, 3, 4, 1])

# %%
df['fasting blood sugar'].unique()
# Out:
# array([0, 1])

# %%
df['resting ecg'].unique()
# Out:
# array([0, 1, 2])

# %%
df["exercise angina"].unique()
# Out:
# array([0, 1])

# %%
df['ST slope'].unique()
# Out:
# array([1, 2, 3, 0])

# %%
df[df['ST slope']==3]
# Out:
#       age  sex  chest pain type  resting bp s  cholesterol  \
# 248    48    1                4           122          275
# 304    62    0                4           120            0
# 308    53    1                2           130            0
# 310    57    1                4            95            0
# 315    53    1                4            80            0
# ...   ...  ...              ...           ...          ...
# 1073   42    1                3           120          240
# 1123   56    1                4           130          283
# 1172   58    1                4           114          318
# 1176   56    1                2           120          240
# 1179   44    1                4           120          169
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 248                     1            1             150                1
# 304                     1            1             123                1
# ...

# %%
df[df['oldpeak'] < 0.0]
# Out:
#      age  sex  chest pain type  resting bp s  cholesterol  \
# 322   63    1                4           100            0
# 325   46    1                4           100            0
# 326   42    1                4           105            0
# 327   45    1                3           110            0
# 332   56    1                4           115            0
# 333   38    1                3           100            0
# 335   51    1                4           130            0
# 336   62    1                1           120            0
# 353   56    1                4           120            0
# 408   62    1                4           115            0
# 414   56    1                3           125            0
# 422   66    1                3           120            0
# 513   35    1                3           123          161
#
#      fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 322                    1            0             109                0
# ...

# %%
# set null value to extra value of the feature 
df.loc[df['ST slope']==3 ,'ST slope']=np.NaN

# %%
df.loc[df['oldpeak'] < 0.0 ,'oldpeak']=np.NaN

# %%
df.loc[df['ST slope'] == 3 , 'ST slope'] = np.NaN

# %%
df['target'].unique()
# Out:
# array([0, 1])

# %%
df.isnull().sum()
# Out:
# age                     0
# sex                     0
# chest pain type         0
# resting bp s            0
# cholesterol             0
# fasting blood sugar     0
# resting ecg             0
# max heart rate          0
# exercise angina         0
# oldpeak                13
# ST slope               81
# target                  0
# dtype: int64

# %% [markdown]
# <h3>Graphical veiw of Null values</h3>

# %%
plt.figure(figsize=(10,4))
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# <h3>Fill the Null values</h3>

# %%
df = df.fillna(df.median())

# %%
df['ST slope'].unique()
# Out:
# array([1., 2., 0.])

# %% [markdown]
# <br>
# <h3>Duplicates value in dataset </h3>
# <hr>
# <br>

# %%
df[df.duplicated(keep=False)]
# Out:
#       age  sex  chest pain type  resting bp s  cholesterol  \
# 90     49    0                2           110          208
# 163    49    0                2           110          208
# 556    58    1                3           150          219
# 604    58    1                3           150          219
# 617    70    1                4           130          322
# ...   ...  ...              ...           ...          ...
# 1156   42    1                3           130          180
# 1157   61    1                4           140          207
# 1158   66    1                4           160          228
# 1159   46    1                4           140          311
# 1160   71    0                4           112          149
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 90                      0            0             160                0
# 163                     0            0             160                0
# ...

# %% [markdown]
# <h3>Drop duplicate value from dataset</h3>

# %%
df=df.drop_duplicates()

# %%
print(True) if df.duplicated().sum() else False
# Out:
# False

# %%
df.shape
# Out:
# (918, 12)

# %% [markdown]
# <br>
# <h3>Statistics summary of Dataset</h3>
# <hr>
# <br>

# %%
df.describe()
# Out:
#               age         sex  chest pain type  resting bp s  cholesterol  \
# count  918.000000  918.000000       918.000000    918.000000   918.000000
# mean    53.510893    0.789760         3.251634    132.396514   198.799564
# std      9.432617    0.407701         0.931031     18.514154   109.384145
# min     28.000000    0.000000         1.000000      0.000000     0.000000
# 25%     47.000000    1.000000         3.000000    120.000000   173.250000
# 50%     54.000000    1.000000         4.000000    130.000000   223.000000
# 75%     60.000000    1.000000         4.000000    140.000000   267.000000
# max     77.000000    1.000000         4.000000    200.000000   603.000000
#
#        fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# count           918.000000   918.000000      918.000000       918.000000
# mean              0.233115     0.603486      136.809368         0.404139
# std               0.423046     0.805968       25.460334         0.490992
# ...

# %%
# saving cleaned dataset
df.to_csv('cleaned_dataset.csv')

# %%
heat_map = sns.heatmap(df.corr(method='pearson'), annot=True, fmt='.2f', linewidths=1)
heat_map.set_xticklabels(heat_map.get_xticklabels(), rotation=50);

# %% [markdown]
# <br>
# <br>
# <h1 align="center">Data Visualization</h1>
# <hr>
# <br>
# <br>

# %% [markdown]
# ### Simple target Variable visualiztion

# %%
f = sns.countplot(x='target', data=df)
f.set_title("Heart disease presence distribution")
f.set_xticklabels(['No Heart disease', 'Heart Disease'])
plt.xlabel("");

# %% [markdown]
# ### visualliztion of all feature with respect to target Variable

# %%
sns.pairplot(df,hue="target",diag_kind='hist')
plt.show()

# %% [markdown]
# ### Display age distribution based on heart disease

# %%
sns.displot(df, x="age", hue="target")
plt.legend(["Disease", "No Disease"])
plt.show()

# %%
df['Age_Category'] = pd.cut(df['age'],bins=list(np.arange(25, 85, 5)))

# %%
plt.subplot(121)
df[df['target']==1].groupby('Age_Category')['age'].count().plot(kind='bar')
plt.title('Age Distribution of Patients with +ve Heart Diagonsis')

plt.subplot(122)
df[df['target']==0].groupby('Age_Category')['age'].count().plot(kind='bar')
plt.title('Age Distribution of Patients with -ve Heart Diagonsis')
# Out:
# Text(0.5, 1.0, 'Age Distribution of Patients with -ve Heart Diagonsis')

# %%
plt.scatter(x=df.age[df.target==1], y=df['max heart rate'][(df.target==1)], c="red", s=60)
plt.scatter(x=df.age[df.target==0], y=df['max heart rate'][(df.target==0)], s=60)
plt.legend(["Disease", "No Disease"])
plt.xlabel("Age")
plt.ylabel("Maximum Heart Rate");

# %%
fig, ax = plt.subplots(figsize=(8,5))
name = df['sex']
ax = sns.countplot(x='sex', hue='target', data=df, palette='Set2')
ax.set_title("Sex Distribution according to Target", fontsize = 13, weight = 'bold')

totals = []
for i in ax.patches:
    totals.append(i.get_height())
total = sum(totals)
for i in ax.patches:
    ax.text(i.get_x()+.05, i.get_height()-15,
            str(round((i.get_height()/total)*100, 2))+'%', fontsize=14,
                color='white', weight = 'bold')  
plt.tight_layout()

# %%
pd.crosstab(df["chest pain type"],df.target).plot(kind = "bar", figsize = (8, 6))
plt.title('Heart Disease Frequency According to Chest Pain Type')
plt.xlabel('Chest Pain Type')
plt.xticks(np.arange(4), ('typical angina', 'atypical angina', 'non-anginal pain', 'asymptomatic'), rotation = 0)
plt.ylabel('Frequency')
plt.show()

# %%
sns.displot(df, x="resting bp s", hue="target")
plt.show()
